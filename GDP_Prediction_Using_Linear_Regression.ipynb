# %% [markdown]
# <a href="https://colab.research.google.com/github/Hafiz-wave/Project-for-Data-Science-Analyst/blob/main/GDP_Prediction_Using_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
lifesat.shape
# Out:
# (27, 3)

# %%
#downloading dataset

data_root = 'https://github.com/ageron/data/raw/main/'

lifesat = pd.read_csv(data_root + 'lifesat/lifesat.csv')

lifesat.head()
# Out:
#    Country  GDP per capita (USD)  Life satisfaction
# 0   Russia          26456.387938                5.8
# 1   Greece          27287.083401                5.4
# 2   Turkey          28384.987785                5.5
# 3   Latvia          29932.493910                5.9
# 4  Hungary          31007.768407                5.6

# %% [markdown]
# Metion X and Yaxis

# %% [markdown]
# use .value() to conv to array

# %%
lifesat.columns
# Out:
# Index(['Country', 'GDP per capita (USD)', 'Life satisfaction'], dtype='object')

# %%
name_col = name_col = ["Country","GDPpercapitaUSD","Lifesatisfaction"]

lifesat.columns = name_col
lifesat.head(10)
# Out:
#     Country  GDPpercapitaUSD  Lifesatisfaction
# 0    Russia     26456.387938               5.8
# 1    Greece     27287.083401               5.4
# 2    Turkey     28384.987785               5.5
# 3    Latvia     29932.493910               5.9
# 4   Hungary     31007.768407               5.6
# 5  Portugal     32181.154537               5.4
# 6    Poland     32238.157259               6.1
# 7   Estonia     35638.421351               5.7
# 8     Spain     36215.447591               6.3
# 9  Slovenia     36547.738956               5.9

# %%
lifesat.dtypes
# Out:
# Country              object
# GDPpercapitaUSD     float64
# Lifesatisfaction    float64
# dtype: object

# %%
lifesat.describe (include = 'all')
# Out:
#        Country  GDPpercapitaUSD  Lifesatisfaction
# count       27        27.000000         27.000000
# unique      27              NaN               NaN
# top     Russia              NaN               NaN
# freq         1              NaN               NaN
# mean       NaN     41564.521771          6.566667
# std        NaN      9631.452319          0.765607
# min        NaN     26456.387938          5.400000
# 25%        NaN     33938.289305          5.900000
# 50%        NaN     41627.129269          6.800000
# 75%        NaN     49690.580269          7.300000
# max        NaN     60235.728492          7.600000

# %%
lifesat.isnull().sum()
# Out:
# Country             0
# GDPpercapitaUSD     0
# Lifesatisfaction    0
# dtype: int64

# %%
lifesat.dropna(subset =['GDPpercapitaUSD'], axis = 0, inplace = True)
lifesat.dropna(subset =['Lifesatisfaction'], axis = 0, inplace = True)

# %%
lifesat.columns
# Out:
# Index(['Country', 'GDPpercapitaUSD', 'Lifesatisfaction'], dtype='object')

# %%
mean_norm = lifesat['GDPpercapitaUSD'].astype('float').mean()
mean_norm = lifesat['Lifesatisfaction'].astype('float').mean()

# %%
X = lifesat[['GDPpercapitaUSD']].values
y = lifesat[['Lifesatisfaction' ]].values

lifesat.plot( kind = 'scatter', grid = True, x = 'GDPpercapitaUSD', y = 'Lifesatisfaction')

plt.show()

# %%
#select linear model

model = LinearRegression()

#Train the model

model.fit (X,y)
# Out:
# LinearRegression()

# %%
# make a prediction for cyprus

X_new = [[37_655.2]]

print(model.predict(X_new))
# Out:
# [[6.30165767]]

# %%
lifesat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           27 non-null     object
#  1   GDPpercapitaUSD   27 non-null     float64
#  2   Lifesatisfaction  27 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 776.0+ bytes

# %%
import numpy as np

msk = np.random.rand(len(lifesat)) < 0.80
train = lifesat[msk]
test = lifesat[~msk]

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
#training the model
train_x = np.asanyarray(train[['GDPpercapitaUSD']])
train_y = np.asanyarray(train[['Lifesatisfaction']])

poly = PolynomialFeatures(degree=2)

train_x_poly = poly.fit_transform(train_x)

clf = linear_model.LinearRegression()

train_y_ = clf.fit(train_x_poly, train_y)


#Prediction model

test_x = np.asanyarray(test[['GDPpercapitaUSD']])
test_y = np.asanyarray(test[['Lifesatisfaction']])

test_x_poly = poly.fit_transform(test_x)

test_y_ = clf.predict(test_x_poly)

#Evaluation

from sklearn.metrics import r2_score

print ('The R2 score is', (r2_score(test_y, test_y_))*100)
print ('The MSE is', np.mean((test_y_ - test_y)**2))
# Out:
# The R2 score is 44.977922831565834
# The MSE is 0.2255905163905801

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
#training the model
train_x = np.asanyarray(train[['GDPpercapitaUSD']])
train_y = np.asanyarray(train[['Lifesatisfaction']])

poly = PolynomialFeatures(degree=2)

train_x_poly = poly.fit_transform(train_x)

clf = linear_model.LinearRegression()

train_y_ = clf.fit(train_x_poly, train_y)


#Prediction model

test_x = np.asanyarray(test[['GDPpercapitaUSD']])
test_y = np.asanyarray(test[['Lifesatisfaction']])

test_x_poly = poly.fit_transform(test_x)

test_y_ = clf.predict(test_x_poly)

#Evaluation

from sklearn.metrics import r2_score

print ('The R2 score is', (r2_score(test_y, test_y_))*100)
print ('The MSE is', np.mean((test_y_ - test_y)**2))
# Out:
# The R2 score is 44.977922831565834
# The MSE is 0.2255905163905801
